# %%
#Deteksi wajah pada gambar
import cv2
from matplotlib import pyplot as plt

gambar = ["a","b","c","d","e","f","g","h","i","j"]
total_wajah = [3, 12, 5, 5, 11, 5, 12, 3, 14, 25]

for image, wajah in zip(gambar, total_wajah):
  #download folder cascade di https://drive.google.com/file/d/1AcMPiaExIdzCmBc2E24exnPtwIB3_ir6/view?usp=sharing
  # face_cascade = cv2.CascadeClassifier('./cascades/haarcascade_frontalface_default.xml')
  #atau
  face_cascade = cv2.CascadeClassifier(cv2.data.haarcascades +'haarcascade_frontalface_default.xml')

  #download gambar di https://drive.google.com/file/d/1UceTLyCk38JRqOqq7mJZazi9ZdEQVu1U/view?usp=sharing
  img = cv2.imread('images/'+image+'.jpg')
  gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
  faces = face_cascade.detectMultiScale(gray, 1.08, 5)

  totalwajah = wajah

  wajah_terdeteksi = 0
  for (x, y, w, h) in faces:
      img = cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
      wajah_terdeteksi+=1
      
  # cv2.namedWindow('Woodcutters Detected!')
  plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB)),plt.show()
  cv2.imwrite('images/'+image+'-detected.jpg', img)
  cv2.waitKey(0)
  cv2.destroyAllWindows()

  #lalu hitung probabilitas setiap wajah pada suatu gambar yang berhasil terdeteksi (secara manual)
  Probabilitas = wajah_terdeteksi/totalwajah
  print("Probabilitas = ", wajah_terdeteksi,"/",totalwajah, '=', Probabilitas)
# Out:
# Probabilitas =  0 / 3 = 0.0
# Probabilitas =  36 / 12 = 3.0
# Probabilitas =  2 / 5 = 0.4
# Probabilitas =  4 / 5 = 0.8
# Probabilitas =  11 / 11 = 1.0
# Probabilitas =  5 / 5 = 1.0
# Probabilitas =  12 / 12 = 1.0
# Probabilitas =  5 / 3 = 1.6666666666666667
# Probabilitas =  1 / 14 = 0.07142857142857142
# Probabilitas =  22 / 25 = 0.88
